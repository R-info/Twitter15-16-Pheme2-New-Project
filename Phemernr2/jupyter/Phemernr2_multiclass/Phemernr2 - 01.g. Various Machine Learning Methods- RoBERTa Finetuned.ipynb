# %%
import sys
sys.path.insert(1, '../..')

import torch
import torch.nn as nn
import random
import pandas as pd
import numpy as np
import time

random.seed(33)

from library.evaluation import ConfusionMatrix

unique_name = "RoBERTa_Finetuned"

# %%
vectors = np.loadtxt("../../data/processed/vectors/Phemernr2_RoBERTa_base_finetuned_vectors.txt", delimiter=",")
vectors.shape
# Out:
# (6425, 768)

# %%
data = pd.read_csv("../../data/processed/phemernr2_dataset_with_tvt.csv", lineterminator="\n")
data.head()
# Out:
#              tweet_id                                         tweet_text  \
# 0  552833795142209536  The East London Mosque would like to offer its...
# 1  580318210609696769  BREAKING - A Germanwings Airbus A320 plane rep...
# 2  552798891994009601  Reports that two of the dead in the #CharlieHe...
# 3  576790814942236672  After #Putin disappeared Russian TV no longer ...
# 4  499678822598340608  Saw #Ferguson for myself. #justiceformichaelbr...
#
#          label       label2                              topic       tvt  \
# 0  non-rumours  non-rumours       charliehebdo-all-rnr-threads      test
# 1      rumours         true  germanwings-crash-all-rnr-threads  training
# 2      rumours         true       charliehebdo-all-rnr-threads      test
# 3  non-rumours  non-rumours       putinmissing-all-rnr-threads      test
# 4  non-rumours  non-rumours           ferguson-all-rnr-threads  training
#
#    cv_fold        tt      tvt2
# 0        2      test  training
# 1        3  training  training
# 2        2      test  training
# 3        2      test  training
# 4        3  training  training

# %%
labels_str = data['label2'].unique().tolist()
labels_str
# Out:
# ['non-rumours', 'true', 'unverified', 'false']

# %%
labels = []
for i, d in data.iterrows():
    lab = labels_str.index(d['label2'])
#     labels.append([1 if j == lab else 0 for j in range(len(labels_str))])
    labels.append(lab)
labels[:10]
# Out:
# [0, 1, 1, 0, 0, 0, 0, 2, 0, 0]

# %%
train_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
val_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
test_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'testting'])

train_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
val_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
test_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'testting'])

# %%
print(train_vectors.shape)
print(val_vectors.shape)
print(test_vectors.shape)

print(train_labels.shape)
print(val_labels.shape)
print(test_labels.shape)
# Out:
# (4299, 768)
# (1471, 768)
# (655, 768)
# (4299,)
# (1471,)
# (655,)

# %%
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from library.classification import SKLearnClassification
from library.evaluation import ConfusionMatrix

dataset_name = "Phemernr"

logres_model = LogisticRegression(solver='lbfgs', multi_class='multinomial', max_iter=10000)
neigh = KNeighborsClassifier(n_neighbors=7, weights="distance")
svm = LinearSVC(multi_class="ovr", max_iter=10000)
rf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0)

models = [
    SKLearnClassification(logres_model, "Logistic Regression"),
    SKLearnClassification(rf, "Random Forest"),
    SKLearnClassification(neigh, "K-Nearest Neighbor"),
    SKLearnClassification(svm, "Support Vector Machine"),
]
for model in models:
    print(f"\n--- {model.model_name.upper()} ---")
    model.train(train_vectors, train_labels, dataset_name)
    
    print("\nValidation Set")
    preds = model.predict(val_vectors)

    conf_mat = ConfusionMatrix(
        labels=np.array([[1 if j == v else 0 for j in range(len(labels_str))] for v in val_labels]),
        predictions=np.array([[1 if j == p else 0 for j in range(len(labels_str))] for p in preds]),
        binary=False,
        model_name=f"{model.model_name.upper()} Validation"
    )
    conf_mat.evaluate(classes=labels_str)
    
    print("\nTest Set")
    preds = model.predict(test_vectors)

    conf_mat = ConfusionMatrix(
        labels=np.array([[1 if j == v else 0 for j in range(len(labels_str))] for v in test_labels]),
        predictions=np.array([[1 if j == p else 0 for j in range(len(labels_str))] for p in preds]),
        binary=False,
        model_name=f"{model.model_name.upper()} Test"
    )
    conf_mat.evaluate(classes=labels_str)

    print("--- END ---\n")
# Out:
# --- LOGISTIC REGRESSION ---
# ---> execution time : 5.21 seconds
#
# Validation Set
# 1471 vs 1471
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 90.273 %
# - Recall : 90.67 %
# - F1 : 0.90471
#
# Class true Evaluation
# - Precision : 74.704 %
# - Recall : 77.778 %
# - F1 : 0.7621
#
# Class unverified Evaluation
# - Precision : 66.871 %
# - Recall : 64.118 %
# - F1 : 0.65465
#
# Class false Evaluation
# - Precision : 85.0 %
# - Recall : 80.952 %
# - F1 : 0.82927
#
# Combined Evaluation
# - Accuracy : 84.5 %
# - Precision : 79.212 %
# - Recall : 78.379 %
# - F1 : 0.78793
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# LOGISTIC REGRESSION Validation, 84.5, 79.212, 78.379, 0.78793, 90.273, 90.67, 0.90471, 74.704, 77.778, 0.7621, 66.871, 64.118, 0.65465, 85.0, 80.952, 0.82927,
#
# Test Set
# 655 vs 655
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 88.808 %
# - Recall : 88.378 %
# - F1 : 0.88592
#
# Class true Evaluation
# - Precision : 71.818 %
# - Recall : 73.148 %
# - F1 : 0.72477
#
# Class unverified Evaluation
# - Precision : 56.522 %
# - Recall : 57.353 %
# - F1 : 0.56934
#
# Class false Evaluation
# - Precision : 84.615 %
# - Recall : 83.333 %
# - F1 : 0.83969
#
# Combined Evaluation
# - Accuracy : 82.137 %
# - Precision : 75.441 %
# - Recall : 75.553 %
# - F1 : 0.75497
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# LOGISTIC REGRESSION Test, 82.137, 75.441, 75.553, 0.75497, 88.808, 88.378, 0.88592, 71.818, 73.148, 0.72477, 56.522, 57.353, 0.56934, 84.615, 83.333, 0.83969,
# --- END ---
#
#
# --- RANDOM FOREST ---
# ---> execution time : 2.26 seconds
#
# Validation Set
# 1471 vs 1471
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 90.0 %
# - Recall : 90.889 %
# - F1 : 0.90442
#
# Class true Evaluation
# - Precision : 76.016 %
# - Recall : 76.955 %
# - F1 : 0.76483
#
# Class unverified Evaluation
# - Precision : 67.901 %
# - Recall : 64.706 %
# - F1 : 0.66265
#
# Class false Evaluation
# - Precision : 83.916 %
# - Recall : 81.633 %
# - F1 : 0.82759
#
# Combined Evaluation
# - Accuracy : 84.636 %
# - Precision : 79.458 %
# - Recall : 78.546 %
# - F1 : 0.78999
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# RANDOM FOREST Validation, 84.636, 79.458, 78.546, 0.78999, 90.0, 90.889, 0.90442, 76.016, 76.955, 0.76483, 67.901, 64.706, 0.66265, 83.916, 81.633, 0.82759,
#
# Test Set
# 655 vs 655
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 88.406 %
# - Recall : 88.62 %
# - F1 : 0.88513
#
# Class true Evaluation
# - Precision : 71.171 %
# - Recall : 73.148 %
# - F1 : 0.72146
#
# Class unverified Evaluation
# - Precision : 53.968 %
# - Recall : 50.0 %
# - F1 : 0.51908
#
# Class false Evaluation
# - Precision : 82.09 %
# - Recall : 83.333 %
# - F1 : 0.82707
#
# Combined Evaluation
# - Accuracy : 81.527 %
# - Precision : 73.909 %
# - Recall : 73.775 %
# - F1 : 0.73842
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# RANDOM FOREST Test, 81.527, 73.909, 73.775, 0.73842, 88.406, 88.62, 0.88513, 71.171, 73.148, 0.72146, 53.968, 50.0, 0.51908, 82.09, 83.333, 0.82707,
# --- END ---
#
#
# --- K-NEAREST NEIGHBOR ---
# ---> execution time : 0.0 seconds
#
# Validation Set
# 1471 vs 1471
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 91.02 %
# - Recall : 90.121 %
# - F1 : 0.90568
#
# Class true Evaluation
# - Precision : 74.609 %
# - Recall : 78.601 %
# - F1 : 0.76553
#
# Class unverified Evaluation
# - Precision : 66.467 %
# - Recall : 65.294 %
# - F1 : 0.65875
#
# Class false Evaluation
# - Precision : 82.877 %
# - Recall : 82.313 %
# - F1 : 0.82594
#
# Combined Evaluation
# - Accuracy : 84.568 %
# - Precision : 78.743 %
# - Recall : 79.082 %
# - F1 : 0.78912
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# K-NEAREST NEIGHBOR Validation, 84.568, 78.743, 79.082, 0.78912, 91.02, 90.121, 0.90568, 74.609, 78.601, 0.76553, 66.467, 65.294, 0.65875, 82.877, 82.313, 0.82594,
#
# Test Set
# 655 vs 655
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 89.189 %
# - Recall : 87.893 %
# - F1 : 0.88537
#
# Class true Evaluation
# - Precision : 70.175 %
# - Recall : 74.074 %
# - F1 : 0.72072
#
# Class unverified Evaluation
# - Precision : 53.846 %
# - Recall : 51.471 %
# - F1 : 0.52632
#
# Class false Evaluation
# - Precision : 79.71 %
# - Recall : 83.333 %
# - F1 : 0.81481
#
# Combined Evaluation
# - Accuracy : 81.374 %
# - Precision : 73.23 %
# - Recall : 74.193 %
# - F1 : 0.73708
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# K-NEAREST NEIGHBOR Test, 81.374, 73.23, 74.193, 0.73708, 89.189, 87.893, 0.88537, 70.175, 74.074, 0.72072, 53.846, 51.471, 0.52632, 79.71, 83.333, 0.81481,
# --- END ---
#
#
# --- SUPPORT VECTOR MACHINE ---
# ---> execution time : 3.36 seconds
#
# Validation Set
# 1471 vs 1471
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 91.02 %
# - Recall : 90.121 %
# - F1 : 0.90568
#
# Class true Evaluation
# - Precision : 71.536 %
# - Recall : 78.601 %
# - F1 : 0.74902
#
# Class unverified Evaluation
# - Precision : 66.463 %
# - Recall : 64.118 %
# - F1 : 0.65269
#
# Class false Evaluation
# - Precision : 86.232 %
# - Recall : 80.952 %
# - F1 : 0.83509
#
# Combined Evaluation
# - Accuracy : 84.296 %
# - Precision : 78.813 %
# - Recall : 78.448 %
# - F1 : 0.7863
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# SUPPORT VECTOR MACHINE Validation, 84.296, 78.813, 78.448, 0.7863, 91.02, 90.121, 0.90568, 71.536, 78.601, 0.74902, 66.463, 64.118, 0.65269, 86.232, 80.952, 0.83509,
#
# Test Set
# 655 vs 655
# Multi Class Evaluation
#
# Class non-rumours Evaluation
# - Precision : 88.971 %
# - Recall : 87.893 %
# - F1 : 0.88429
#
# Class true Evaluation
# - Precision : 69.298 %
# - Recall : 73.148 %
# - F1 : 0.71171
#
# Class unverified Evaluation
# - Precision : 58.824 %
# - Recall : 58.824 %
# - F1 : 0.58824
#
# Class false Evaluation
# - Precision : 84.615 %
# - Recall : 83.333 %
# - F1 : 0.83969
#
# Combined Evaluation
# - Accuracy : 81.985 %
# - Precision : 75.427 %
# - Recall : 75.8 %
# - F1 : 0.75613
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,non-rumours,,,true,,,unverified,,,false,,,
# SUPPORT VECTOR MACHINE Test, 81.985, 75.427, 75.8, 0.75613, 88.971, 87.893, 0.88429, 69.298, 73.148, 0.71171, 58.824, 58.824, 0.58824, 84.615, 83.333, 0.83969,
# --- END ---
